# %%
import pickle
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
step = 60

# %%
def load_pickle(filename):
    if os.path.exists(filename):
        print("loaded the q table")
        with open(filename, 'rb') as f:
            return pickle.load(f)

# %%
def load_q_table(filename):
    # Ensure the q_table_data is not None
    q_table_data = load_pickle(filename)
    # print(q_table)if q_table_data is not None:
    q_table, rewards_per_episode, epsilon = q_table_data
    print("len (rewards_per_episode):", len(rewards_per_episode))
    print("len (epsilon):", epsilon)
    # Convert to DataFrame
    df = pd.DataFrame.from_dict(q_table, orient='index')

    # Reset index to flatten the DataFrame
    df.reset_index(inplace=True)

    # Rename columns for clarity
    df.columns = ['parity', 'mim', 'mip', 'disease'] + list(df.columns[4:])

    # Display the DataFrame
    return df

def load_q_table_no_sick(filename):
    # Ensure the q_table_data is not None
    q_table_data = load_pickle(filename)
    # print(q_table)if q_table_data is not None:
    q_table, rewards_per_episode, epsilon = q_table_data
    print("len (rewards_per_episode):", len(rewards_per_episode))
    print("len (epsilon):", epsilon)
    
    # Convert to DataFrame
    df = pd.DataFrame.from_dict(q_table, orient='index')

    # Reset index to flatten the DataFrame
    df.reset_index(inplace=True)

    # Rename columns for clarity
    df.columns = ['parity', 'mim', 'mip'] + list(df.columns[3:])

    # Display the DataFrame
    return df

# %%
df = load_q_table("q_table_afterSlaughterDebug.pkl")
df
# Out:
# loaded the q table
# len (rewards_per_episode): 1000000
# len (epsilon): 0.3
#       parity  mim  mip  disease          Keep          Cull
# 0          0    0    9        0  34227.652346  32769.564655
# 1          1    0    8        0  33782.611144  32780.902725
# 2          1    0    8        1  33767.392442  32549.351693
# 3          1    0    9        0  34367.405613  32771.823742
# 4          1    0    9        1  33984.514345  32572.748608
# ...      ...  ...  ...      ...           ...           ...
# 2876      12   20    5        1  18706.931403  32671.645353
# 2877      12   20    6        0   7827.497035  33042.003742
# 2878      12   20    6        1  17796.331624  32645.097231
# 2879      12   20    7        0  32066.035120  33002.611332
# 2880      12   20    7        1  32087.953156  32723.440272
#
# [2881 rows x 6 columns]

# %%
df_grouped = df.groupby('disease').mean()[['Keep','Cull']]
df_grouped
# Out:
#                  Keep          Cull
# disease
# 0        31330.002194  32932.370024
# 1        31369.335896  32509.840032

# %%
# value of a replacement heifer (keeping) is
display(df[df['parity'] == 0])
replacement_value = df[df['parity'] == 0]['Keep'][0]
print(replacement_value) # <- this value is the expected max outcome of having this animal
print(replacement_value/60) # <- to month
# Out:
#    parity  mim  mip  disease          Keep          Cull
# 0       0    0    9        0  34227.652346  32769.564655
# 34227.65234615512
# 570.4608724359186

# %%
# parity = 1
# Open cows
df_parity_1_open = df[(df['parity'] == 1) & (df['mip'] == 0)]  # Open cows
df_parity_1_open_grouped = df_parity_1_open.groupby('mim').mean()[['Keep','Cull']].reset_index()
display(df_parity_1_open_grouped)

# Preg cows
df_parity_1_preg = df[(df['parity'] == 1) & (df['mip'] != 0)]  # preg
df_parity_1_preg_grouped = df_parity_1_preg.groupby('mim').mean()[['Keep','Cull']].reset_index()
display(df_parity_1_preg_grouped)

# Plot the Q-values of 'Keep' and 'Cull' against 'mim'
plt.figure(figsize=(10, 5))
plt.plot(df_parity_1_open_grouped['mim'], df_parity_1_open_grouped['Keep']/step, label='Open cow Keep', marker = 'o')
plt.plot(df_parity_1_preg_grouped['mim'], df_parity_1_preg_grouped['Keep']/step, label='Preg cow Keep', marker = 'o')
plt.plot(df_parity_1_open_grouped['mim'], df_parity_1_open_grouped['Cull']/step, label='Cull', marker = 'o', linestyle='dashed') # because culling price is not related to preg or not
# plt.plot(df_parity_1_preg_grouped['mim'], df_parity_1_preg_grouped['Cull']/step, label='Preg cow Cull', marker = 'v', linestyle='dashed')

# Add labels and title
plt.xlabel('Month in Milk')
plt.ylabel('Q-value')
plt.title('Q-values of Keep and Cull for Parity = 1 Cows')
plt.legend()
# Set x-axis to use integer ticks
plt.xticks(df['mim'].unique())

# parity = 2
# Open cows
df_parity_2_open = df[(df['parity'] == 2) & (df['mip'] == 0)]  # Open cows
df_parity_2_open_grouped = df_parity_2_open.groupby('mim').mean()[['Keep','Cull']].reset_index()
display(df_parity_2_open_grouped)

# Preg cows
df_parity_2_preg = df[(df['parity'] == 2) & (df['mip'] != 0)]  # preg
df_parity_2_preg_grouped = df_parity_2_preg.groupby('mim').mean()[['Keep','Cull']].reset_index()
# display(df_parity_2_preg_grouped)

plt.figure(figsize=(10, 5))
plt.plot(df_parity_2_open_grouped['mim'], df_parity_2_open_grouped['Keep']/step, label='Open cow Keep', marker = 'o')
plt.plot(df_parity_2_preg_grouped['mim'], df_parity_2_preg_grouped['Keep']/step, label='Preg cow Keep', marker = 'o')
plt.plot(df_parity_2_open_grouped['mim'], df_parity_2_open_grouped['Cull']/step, label='Cull', marker = 'o', linestyle='dashed') # because culling price is not related to preg or not

# # parity = 3
# # Open cows
# df_parity_3_open = df[(df['parity'] == 3) & (df['mip'] == 0)]  # Open cows
# df_parity_3_open_grouped = df_parity_3_open.groupby('mim').mean()[['Keep','Cull']].reset_index()
# display(df_parity_3_open_grouped)


# Add labels and title
plt.xlabel('Month in Milk')
plt.ylabel('Q-value')
plt.title('Q-values of Keep and Cull for Parity = 2 Cows')
plt.legend()
# Set x-axis to use integer ticks
plt.xticks(df['mim'].unique())

# Display the plot
plt.show()
# Out:
#     mim          Keep          Cull
# 0     1  34451.921895  32151.306895
# 1     2  34486.782745  32641.263963
# 2     3  34396.257233  32657.045490
# 3     4  33946.988828  32650.066394
# 4     5  34082.029506  32670.181892
# 5     6  33794.685557  32641.975524
# 6     7  33740.321659  32668.566766
# 7     8  33547.660357  32647.251395
# 8     9  33430.361942  32685.615980
# 9    10  33257.749899  32678.739218
# 10   11  33050.578550  32730.854370
# 11   12  32833.221352  32680.901513
# 12   13  32771.963728  32713.462442
# 13   14  32749.498741  32693.809772
# 14   15  32654.632486  32576.890935
# 15   16  32494.814803  32684.722683
# 16   17  31988.631637  32676.213807
# 17   18  32183.611423  32665.675624
# 18   19  32181.152721  32664.117053
# 19   20   7860.405974  32629.327717
#     mim          Keep          Cull
# 0     0  33975.480886  32668.706692
# 1     4  34514.812663  32655.417907
# 2     5  34328.311110  32648.289353
# 3     6  34194.309466  32661.294958
# 4     7  34066.267507  32677.540360
# 5     8  33987.076139  32687.027907
# 6     9  33926.063057  32686.878881
# 7    10  33874.896274  32680.039027
# 8    11  33813.745481  32703.305422
# 9    12  33760.845460  32704.156941
# 10   13  33647.697442  32701.694299
# 11   14  33450.319795  32690.406322
# 12   15  33315.741355  32600.183802
# 13   16  33108.661685  32590.041677
# 14   17  32886.139544  32555.707261
# 15   18  32668.522454  32556.977727
# 16   19  32606.589946  32586.325351
# 17   20  10002.531751  32645.807523
#     mim          Keep          Cull
# 0     1  34389.909546  32750.706777
# 1     2  34464.863519  32783.601894
# 2     3  34319.991576  32762.374858
# 3     4  34141.210345  32805.162486
# 4     5  33857.268182  32811.628441
# 5     6  33440.100611  32799.893228
# 6     7  33189.506655  32803.002414
# 7     8  33072.017711  32760.683627
# 8     9  32971.808279  32784.716630
# 9    10  32867.955295  32771.700124
# 10   11  32699.597567  32655.902679
# 11   12  32374.562403  32754.546960
# 12   13  32254.930865  32614.665328
# 13   14  32161.944883  32781.822836
# 14   15  32202.491282  32745.413110
# 15   16  31686.555398  32793.634086
# 16   17  32608.659090  31946.623100
# 17   18  32279.110433  32754.768030
# 18   19  32141.510886  32734.890260
# 19   20  10533.663181  32764.285714

# %%
df_parity_1_mip1 = df[(df['parity'] == 1) & (df['mip'] == 1) & (df['disease'] == 0)]  # parity 1, preg cows, healthy
df_parity_1_mip1_sick = df[(df['parity'] == 1) & (df['mip'] == 1) & (df['disease'] == 1)]  # parity 1, preg cows, healthy

display(df_parity_1_mip1)

plt.figure(figsize=(10, 5))
plt.plot(df_parity_1_mip1['mim'], df_parity_1_mip1['Keep']/step, marker = 'o')
plt.plot(df_parity_1_mip1_sick['mim'], df_parity_1_mip1_sick['Keep']/step, marker = 'o')

# Add labels and title
plt.xlabel('Month in Milk')
plt.ylabel('Q-value')
plt.title('Q-values of Parity 1 Cows who get pregnant at different mo.') # expected return for cows that get preg at different MIM
# # Set x-axis to use integer ticks
plt.xticks(df_parity_1_mip1['mim'].unique())
plt.show()
# Out:
#      parity  mim  mip  disease          Keep          Cull
# 13        1    4    1        0  34603.992567  32762.694869
# 17        1    5    1        0  34400.918345  32796.142218
# 23        1    6    1        0  34202.755889  32805.489339
# 31        1    7    1        0  34256.895977  32760.874367
# 41        1    8    1        0  33919.518435  32824.603312
# 53        1    9    1        0  33859.120230  32821.921011
# 67        1   10    1        0  33838.781238  32847.397193
# 83        1   11    1        0  33782.149802  32867.618003
# 99        1   12    1        0  33645.502116  32851.025355
# 115       1   13    1        0  33315.247700  32835.712560
# 131       1   14    1        0  32577.666861  32869.154774
# 147       1   15    1        0  32270.078765  32841.208337
# 163       1   16    1        0  31928.884603  32779.752318
# 179       1   17    1        0  32035.709760  32806.150719
# 195       1   18    1        0  31081.314325  32787.054285
# 211       1   19    1        0  32167.362009  32819.594908
# 227       1   20    1        0   5855.041833  32794.097158

# %%
df = load_q_table_no_sick("q_table.pkl")
df['Diff'] = df['Keep'] - df['Cull']
df[:50]
# Out:
# loaded the q table
# len (rewards_per_episode): 1000000
# len (epsilon): 0.3
#     parity  mim  mip          Keep          Cull         Diff
# 0        0    0    9  37057.034378  35519.428316  1537.606062
# 1        1    0    8  36856.370821  35452.368894  1404.001927
# 2        1    0    9  37216.155464  35494.931975  1721.223489
# 3        1    1    0  37357.801505  35548.670153  1809.131352
# 4        1    2    0  37223.340739  35486.014224  1737.326515
# 5        1    3    0  37320.216161  35478.975622  1841.240539
# 6        1    4    0  37224.107329  35506.144781  1717.962548
# 7        1    4    1  37258.549485  35521.035920  1737.513565
# 8        1    5    0  36804.224845  35523.572688  1280.652157
# 9        1    5    1  37408.658676  35453.351734  1955.306942
# 10       1    5    2  37162.188365  35474.658120  1687.530245
# 11       1    6    0  36667.512444  35535.936516  1131.575928
# 12       1    6    1  36796.751146  35453.940878  1342.810267
# 13       1    6    2  37240.343821  35457.439155  1782.904666
# 14       1    6    3  37146.967797  35472.678285  1674.289512
# 15       1    7    0  36395.633043  35439.003161   956.629881
# 16       1    7    1  36791.864384  35421.605444  1370.258940
# 17       1    7    2  36692.020712  35424.521838  1267.498875
# 18       1    7    3  37068.445796  35458.475193  1609.970604
# 19       1    7    4  37148.420122  35480.170018  1668.250104
# 20       1    8    0  36272.968733  35439.093807   833.874927
# 21       1    8    1  36688.576201  35414.062547  1274.513654
# 22       1    8    2  36861.866495  35447.020374  1414.846121
# 23       1    8    3  36746.261647  35440.363962  1305.897685
# 24       1    8    4  36944.190616  35461.808832  1482.381784
# 25       1    8    5  37065.749041  35497.197223  1568.551818
# 26       1    9    0  36134.565966  35368.517071   766.048895
# 27       1    9    1  36694.869571  35441.511237  1253.358335
# 28       1    9    2  36647.853140  35451.689649  1196.163491
# 29       1    9    3  36800.463416  35412.023417  1388.439999
# 30       1    9    4  36654.522392  35449.225118  1205.297274
# 31       1    9    5  36939.638299  35460.256084  1479.382215
# 32       1    9    6  36967.425443  35519.569515  1447.855928
# 33       1   10    0  35916.266630  35451.407941   464.858688
# 34       1   10    1  36564.621638  35491.774974  1072.846664
# 35       1   10    2  36597.168490  35455.175387  1141.993103
# 36       1   10    3  36629.472847  35432.720073  1196.752775
# 37       1   10    4  36780.603016  35417.412812  1363.190204
# 38       1   10    5  36568.938430  35403.385568  1165.552861
# 39       1   10    6  36872.454889  35416.992678  1455.462210
# 40       1   10    7  36896.507976  35450.927147  1445.580828
# 41       1   11    0  35744.097512  35414.580749   329.516763
# 42       1   11    1  36399.856650  35443.200060   956.656591
# 43       1   11    2  36529.399439  35426.581738  1102.817701
# 44       1   11    3  36516.528467  35447.168628  1069.359839
# 45       1   11    4  36563.520829  35393.294785  1170.226043
# 46       1   11    5  36732.238455  35420.506703  1311.731752
# 47       1   11    6  36587.206981  35449.004001  1138.202980
# 48       1   11    7  36834.996982  35444.131791  1390.865191
# 49       1   12    0  35564.106201  35398.857522   165.248680

# %%
# parity = 1
# Open cows
df_parity_1_open = df[(df['parity'] == 1) & (df['mip'] == 0)]  # Open cows
df_parity_1_open_grouped = df_parity_1_open.groupby('mim').mean()[['Keep','Cull']].reset_index()
# display(df_parity_1_open_grouped)

# Preg cows
df_parity_1_preg = df[(df['parity'] == 1) & (df['mip'] != 0)]  # preg
df_parity_1_preg_grouped = df_parity_1_preg.groupby('mim').mean()[['Keep','Cull']].reset_index()
# display(df_parity_1_preg_grouped)

# Plot the Q-values of 'Keep' and 'Cull' against 'mim'
plt.figure(figsize=(10, 5))
plt.plot(df_parity_1_open_grouped['mim'], df_parity_1_open_grouped['Keep']/step, label='Open cow Keep', marker = 'o')
plt.plot(df_parity_1_preg_grouped['mim'], df_parity_1_preg_grouped['Keep']/step, label='Preg cow Keep', marker = 'o')
plt.plot(df_parity_1_open_grouped['mim'], df_parity_1_open_grouped['Cull']/step, label='Cull', marker = 'o', linestyle='dashed') # because culling price is not related to preg or not
# plt.plot(df_parity_1_preg_grouped['mim'], df_parity_1_preg_grouped['Cull']/step, label='Preg cow Cull', marker = 'v', linestyle='dashed')

# Add labels and title
plt.xlabel('Month in Milk')
plt.ylabel('Q-value')
plt.title('Q-values of Keep and Cull for Parity = 1 Cows')
plt.legend()
# Set x-axis to use integer ticks
plt.xticks(df['mim'].unique())

# parity = 2
# Open cows
df_parity_2_open = df[(df['parity'] == 2) & (df['mip'] == 0)]  # Open cows
df_parity_2_open_grouped = df_parity_2_open.groupby('mim').mean()[['Keep','Cull']].reset_index()
# display(df_parity_2_open_grouped)

# Preg cows
df_parity_2_preg = df[(df['parity'] == 2) & (df['mip'] != 0)]  # preg
df_parity_2_preg_grouped = df_parity_2_preg.groupby('mim').mean()[['Keep','Cull']].reset_index()
# display(df_parity_2_preg_grouped)

plt.figure(figsize=(10, 5))
plt.plot(df_parity_2_open_grouped['mim'], df_parity_2_open_grouped['Keep']/step, label='Open cow Keep', marker = 'o')
plt.plot(df_parity_2_preg_grouped['mim'], df_parity_2_preg_grouped['Keep']/step, label='Preg cow Keep', marker = 'o')
plt.plot(df_parity_2_open_grouped['mim'], df_parity_2_open_grouped['Cull']/step, label='Cull', marker = 'o', linestyle='dashed') # because culling price is not related to preg or not

# # parity = 3
# # Open cows
# df_parity_3_open = df[(df['parity'] == 3) & (df['mip'] == 0)]  # Open cows
# df_parity_3_open_grouped = df_parity_3_open.groupby('mim').mean()[['Keep','Cull']].reset_index()
# display(df_parity_3_open_grouped)


# Add labels and title
plt.xlabel('Month in Milk')
plt.ylabel('Q-value')
plt.title('Q-values of Keep and Cull for Parity = 2 Cows')
plt.legend()
# Set x-axis to use integer ticks
plt.xticks(df['mim'].unique())

# Display the plot
plt.show()

# %%
df_parity_1_mip1 = df[(df['parity'] == 1) & (df['mip'] == 1)]  # parity 1, preg cows, healthy
display(df_parity_1_mip1)

plt.figure(figsize=(10, 5))
plt.plot(df_parity_1_mip1['mim'], df_parity_1_mip1['Keep']/step, marker = 'o')

# Add labels and title
plt.xlabel('Month in Milk')
plt.ylabel('Q-value')
plt.title('Q-values of Parity 1 Cows who get pregnant at different mo.') # expected return for cows that get preg at different MIM
# # Set x-axis to use integer ticks
plt.xticks(df_parity_1_mip1['mim'].unique())
plt.show()
# Out:
#      parity  mim  mip          Keep          Cull          Diff
# 7         1    4    1  37258.549485  35521.035920   1737.513565
# 9         1    5    1  37408.658676  35453.351734   1955.306942
# 12        1    6    1  36796.751146  35453.940878   1342.810267
# 16        1    7    1  36791.864384  35421.605444   1370.258940
# 21        1    8    1  36688.576201  35414.062547   1274.513654
# 27        1    9    1  36694.869571  35441.511237   1253.358335
# 34        1   10    1  36564.621638  35491.774974   1072.846664
# 42        1   11    1  36399.856650  35443.200060    956.656591
# 50        1   12    1  36281.294900  35393.323471    887.971430
# 58        1   13    1  36097.831918  35410.843001    686.988917
# 66        1   14    1  35806.110280  35332.065888    474.044392
# 74        1   15    1  35350.219802  35326.995209     23.224593
# 82        1   16    1  35282.546972  35384.496328   -101.949357
# 90        1   17    1  35273.147041  35360.226687    -87.079646
# 98        1   18    1  35241.848408  35454.796955   -212.948547
# 106       1   19    1  35227.777793  35402.186804   -174.409011
# 114       1   20    1   9135.487015  35457.221251 -26321.734236

# %%
df_19m = df[df['mim'] != 20]

### parity = 1
# Open cows
df_parity_1_open = df_19m[(df_19m['parity'] == 1) & (df_19m['mip'] == 0)]  # Open cows
df_parity_1_open_grouped = df_parity_1_open.groupby('mim').mean()[['Diff']].reset_index()
# display(df_parity_1_open_grouped)

# Preg cows
df_parity_1_preg = df_19m[(df_19m['parity'] == 1) & (df_19m['mip'] != 0)]  # preg
df_parity_1_preg_grouped = df_parity_1_preg.groupby('mim').mean()[['Diff']].reset_index()
# display(df_parity_1_preg_grouped)

plt.figure(figsize=(10, 5))
plt.plot(df_parity_1_open_grouped['mim'], df_parity_1_open_grouped['Diff'], label='Open Parity 1 cow', color = 'b', marker = 'o', markerfacecolor='none')
plt.plot(df_parity_1_preg_grouped['mim'], df_parity_1_preg_grouped['Diff'], label='Preg Parity 1 cow', color = 'b', marker = 'o')
# plt.plot(df_parity_1_open_grouped['mim'], df_parity_1_open_grouped['Cull']/step, label='Cull', marker = 'o', linestyle='dashed') # because culling price is not related to preg or not
# plt.plot(df_parity_1_preg_grouped['mim'], df_parity_1_preg_grouped['Cull']/step, label='Preg cow Cull', marker = 'v', linestyle='dashed')

# # Add labels and title
# plt.xlabel('Month in Milk')
# plt.ylabel('Q-value')
# plt.title('Q-values of Keep and Cull for Parity = 1 Cows')
# plt.legend()
# # Set x-axis to use integer ticks
# plt.xticks(df['mim'].unique())

### parity = 2
# Open cows
df_parity_2_open = df_19m[(df_19m['parity'] == 2) & (df_19m['mip'] == 0)]  # Open cows
df_parity_2_open_grouped = df_parity_2_open.groupby('mim').mean()[['Diff']].reset_index()
# display(df_parity_2_open_grouped)

# Preg cows
df_parity_2_preg = df_19m[(df_19m['parity'] == 2) & (df['mip'] != 0)]  # preg
df_parity_2_preg_grouped = df_parity_2_preg.groupby('mim').mean()[['Diff']].reset_index()
# display(df_parity_2_preg_grouped)

# plt.figure(figsize=(10, 5))
plt.plot(df_parity_2_open_grouped['mim'], df_parity_2_open_grouped['Diff'], label='Open Parity 2 cow', color = 'r', marker = '^', markerfacecolor='none')
plt.plot(df_parity_2_preg_grouped['mim'], df_parity_2_preg_grouped['Diff'], label='Preg Parity 2 cow', color = 'r',marker = '^')

### parity = 3
# Open cows
df_parity_3_open = df_19m[(df_19m['parity'] == 3) & (df['mip'] == 0)]  # Open cows
df_parity_3_open_grouped = df_parity_3_open.groupby('mim').mean()[['Diff']].reset_index()

# Preg cows
df_parity_3_preg = df_19m[(df_19m['parity'] == 3) & (df['mip'] != 0)]  # preg
df_parity_3_preg_grouped = df_parity_3_preg.groupby('mim').mean()[['Diff']].reset_index()

plt.plot(df_parity_3_open_grouped['mim'], df_parity_3_open_grouped['Diff'], label='Open Parity 3 cow', color = 'orange', marker = 's', markerfacecolor='none')
plt.plot(df_parity_3_preg_grouped['mim'], df_parity_3_preg_grouped['Diff'], label='Preg Parity 3 cow', color = 'orange',marker = 's')


# Add labels and title
plt.xlabel('Month in Milk')
plt.ylabel('Q-value difference')
plt.title('Q-values Difference for Parity = 1, 2, 3 Cows')
plt.legend()
# Set x-axis to use integer ticks
plt.xticks(df['mim'].unique())

plt.axhline(y=0, color='black', linestyle='dashed')

# Display the plot
plt.show()
# Out:
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/2431608634.py:35: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_parity_2_preg = df_19m[(df_19m['parity'] == 2) & (df['mip'] != 0)]  # preg
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/2431608634.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_parity_3_open = df_19m[(df_19m['parity'] == 3) & (df['mip'] == 0)]  # Open cows
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/2431608634.py:49: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_parity_3_preg = df_19m[(df_19m['parity'] == 3) & (df['mip'] != 0)]  # preg

# %%
### track a cow
def track_a_cow_from_preg(df, parity, starting_mim, starting_mip):
    empty_df = pd.DataFrame(columns=['parity', 'mim', 'mip'])
    mim = starting_mim 
    mip = starting_mip
    while mip < 8:
        selected_row = df[(df['parity'] == parity) & (df['mim'] == mim) & (df['mip'] == mip)]
        empty_df = empty_df.append(selected_row, ignore_index=True)
        mim += 1
        mip += 1
    while mip == 8 or mip == 9: # dry
        selected_row = df[(df['parity'] == parity) & (df['mim'] == 0) & (df['mip'] == mip)]
        empty_df = empty_df.append(selected_row, ignore_index=True)
        mip += 1
    
#     print(len(empty_df))
    empty_df['Month after calving'] = range(starting_mim, starting_mim+9)
    
    return empty_df

def track_a_cow_open(df, parity):
    empty_df = pd.DataFrame(columns=['parity', 'mim', 'mip'])
    mim = 1
    while mim < 20:
        selected_row = df[(df['parity'] == parity) & (df['mim'] == mim) & (df['mip'] == 0)]
        empty_df = empty_df.append(selected_row, ignore_index=True)
        mim += 1
    
    empty_df['Month after calving'] = range(1, 20)
    
    return empty_df

# %%
cow141 = track_a_cow_from_preg(df, 1, 4, 1)
display(cow141)
cow151 = track_a_cow_from_preg(df, 1, 5, 1)
cow161 = track_a_cow_from_preg(df, 1, 6, 1)
cow171 = track_a_cow_from_preg(df, 1, 7, 1)
cow181 = track_a_cow_from_preg(df, 1, 8, 1)
cow191 = track_a_cow_from_preg(df, 1, 9, 1)
cow1101 = track_a_cow_from_preg(df, 1, 10, 1)
open1 = track_a_cow_open(df, 1)
# open1

plt.figure(figsize=(10, 5))
plt.plot(cow141['Month after calving'], cow141['Diff'], label='at MIM = 4', color = 'b', marker = 'o')
# plt.plot(cow151['Month after calving'], cow151['Diff'], label='151 cow', color = 'r', marker = 'o')
# plt.plot(cow161['Month after calving'], cow161['Diff'], label='161 cow', color = 'green', marker = 'o')
plt.plot(cow171['Month after calving'], cow171['Diff'], label='at MIM = 7', color = 'pink', marker = 'o')
# plt.plot(cow181['Month after calving'], cow181['Diff'], label='181 cow', color = 'grey', marker = 'o')
# plt.plot(cow191['Month after calving'], cow191['Diff'], label='191 cow', color = 'c', marker = 'o')
plt.plot(cow1101['Month after calving'], cow1101['Diff'], label='at MIM = 10', color = 'orange', marker = 'o')
# plot all finally pick two

# always open cow
plt.plot(open1['Month after calving'], open1['Diff'], label='Parity 1 open cow', color = 'black', marker = 'o')

# Add labels and title
plt.xlabel('Month after calving')
plt.ylabel('''Q-value difference between 'keep' and 'cull'  ''')
plt.title('Value of cows who get pregnant at different month (Parity = 1)')
plt.legend()
# Set x-axis to use integer ticks
plt.xticks(df['mim'].unique())

plt.axhline(y=0, color='black', linestyle='dashed')

plt.show()
# Out:
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
#   parity mim mip          Keep          Cull         Diff  Month after calving
# 0      1   4   1  37258.549485  35521.035920  1737.513565                    4
# 1      1   5   2  37162.188365  35474.658120  1687.530245                    5
# 2      1   6   3  37146.967797  35472.678285  1674.289512                    6
# 3      1   7   4  37148.420122  35480.170018  1668.250104                    7
# 4      1   8   5  37065.749041  35497.197223  1568.551818                    8
# 5      1   9   6  36967.425443  35519.569515  1447.855928                    9
# 6      1  10   7  36896.507976  35450.927147  1445.580828                   10
# 7      1   0   8  36856.370821  35452.368894  1404.001927                   11
# 8      1   0   9  37216.155464  35494.931975  1721.223489                   12
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)

# %%
cow241 = track_a_cow_from_preg(df, 2, 4, 1)
display(cow241)
cow251 = track_a_cow_from_preg(df, 2, 5, 1)
cow261 = track_a_cow_from_preg(df, 2, 6, 1)
cow271 = track_a_cow_from_preg(df, 2, 7, 1)
cow281 = track_a_cow_from_preg(df, 2, 8, 1)
cow291 = track_a_cow_from_preg(df, 2, 9, 1)
cow2101 = track_a_cow_from_preg(df, 2, 10, 1)
open2 = track_a_cow_open(df, 2)

plt.figure(figsize=(10, 5))
plt.plot(cow241['Month after calving'], cow241['Diff'], label='at MIM = 4', color = 'b', marker = 'o')
# plt.plot(cow251['Month after calving'], cow251['Diff'], label='251 cow', color = 'r', marker = 'o')
# plt.plot(cow261['Month after calving'], cow261['Diff'], label='261 cow', color = 'green', marker = 'o')
plt.plot(cow271['Month after calving'], cow271['Diff'], label='at MIM = 7', color = 'pink', marker = 'o')
# plt.plot(cow281['Month after calving'], cow281['Diff'], label='281 cow', color = 'grey', marker = 'o')
# plt.plot(cow291['Month after calving'], cow291['Diff'], label='291 cow', color = 'c', marker = 'o')
plt.plot(cow2101['Month after calving'], cow2101['Diff'], label='at MIM = 10', color = 'orange', marker = 'o')
# plot all finally pick two

# always open cow
plt.plot(open2['Month after calving'], open2['Diff'], label='Parity 2 open cow', color = 'black', marker = 'o')

# Add labels and title
plt.xlabel('Month after calving')
plt.ylabel('''Q-value difference between 'keep' and 'cull'  ''')
plt.title('Value of cows who get pregnant at different month (Parity = 2)')
plt.legend()
# Set x-axis to use integer ticks
plt.xticks(df['mim'].unique())
plt.axhline(y=0, color='black', linestyle='dashed')

plt.show()
# Out:
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
#   parity mim mip          Keep          Cull         Diff  Month after calving
# 0      2   4   1  37219.581563  35538.653705  1680.927857                    4
# 1      2   5   2  36970.243530  35594.573702  1375.669828                    5
# 2      2   6   3  36740.836824  35454.112737  1286.724087                    6
# 3      2   7   4  36552.282330  35516.979502  1035.302828                    7
# 4      2   8   5  36443.334557  35565.933200   877.401358                    8
# 5      2   9   6  36449.335934  35544.576089   904.759846                    9
# 6      2  10   7  36570.446023  35619.057850   951.388173                   10
# 7      2   0   8  36683.058696  35511.357042  1171.701654                   11
# 8      2   0   9  37242.900969  35546.238564  1696.662406                   12
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
# /var/folders/zv/_4gjbgc57z1gxk8d5dql_0440000gn/T/ipykernel_64388/4205775104.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   empty_df = empty_df.append(selected_row, ignore_index=True)
